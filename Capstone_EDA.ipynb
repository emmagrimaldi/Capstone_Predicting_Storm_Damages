# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 100)

# %%
csv_files = [f for f in os.listdir('data') if f.endswith('.csv')]
csv_files
# Out:
# ['StormEvents_details-ftp_v1.0_d2013_c20170519.csv',
#  'StormEvents_details-ftp_v1.0_d2008_c20180718.csv',
#  'StormEvents_details-ftp_v1.0_d2001_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2005_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2002_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2006_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2010_c20170726.csv',
#  'StormEvents_details-ftp_v1.0_d2017_c20180918.csv',
#  'StormEvents_details-ftp_v1.0_d2016_c20180718.csv',
#  'StormEvents_details-ftp_v1.0_d2015_c20180525.csv',
#  'StormEvents_details-ftp_v1.0_d2011_c20180718.csv',
#  'StormEvents_details-ftp_v1.0_d2014_c20180718.csv',
#  'StormEvents_details-ftp_v1.0_d2007_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2003_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2018_c20180918.csv',
#  'StormEvents_details-ftp_v1.0_d2009_c20180718.csv',
#  'StormEvents_details-ftp_v1.0_d2012_c20170519.csv',
#  'StormEvents_details-ftp_v1.0_d2004_c20170717.csv',
#  'StormEvents_details-ftp_v1.0_d2000_c20170717.csv']

# %%
columns = ['STATE','CZ_TYPE','EVENT_TYPE','BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
       'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
       'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS','BEGIN_RANGE',
       'BEGIN_AZIMUTH', 'END_RANGE', 'END_AZIMUTH','MAGNITUDE_TYPE','MAGNITUDE',
        'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON']

# %%
df = pd.read_csv('data/' + csv_files[0])
df = df[columns]
df.head()
# Out:
#            STATE CZ_TYPE      EVENT_TYPE     BEGIN_DATE_TIME CZ_TIMEZONE  \
# 0  NEW HAMPSHIRE       Z  Winter Weather  23-FEB-13 19:00:00       EST-5
# 1  NEW HAMPSHIRE       Z      Heavy Snow  14-DEC-13 21:00:00       EST-5
# 2  NEW HAMPSHIRE       Z      Heavy Snow  07-MAR-13 15:00:00       EST-5
# 3  NEW HAMPSHIRE       Z     Strong Wind  07-OCT-13 18:30:00       EST-5
# 4  NEW HAMPSHIRE       Z      Heavy Snow  08-FEB-13 15:00:00       EST-5
#
#         END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 0  25-FEB-13 04:00:00                0                  0              0
# 1  15-DEC-13 13:00:00                0                  0              0
# 2  09-MAR-13 09:00:00                0                  0              0
# 3  07-OCT-13 18:30:00                0                  0              0
# 4  09-FEB-13 17:00:00                0                  0              0
#
#    DEATHS_INDIRECT DAMAGE_PROPERTY DAMAGE_CROPS  BEGIN_RANGE BEGIN_AZIMUTH  \
# 0                0           0.00K        0.00K          NaN           NaN
# 1                0           0.00K        0.00K          NaN           NaN
# 2                0           0.00K        0.00K          NaN           NaN
# 3                0           3.00K        0.00K          NaN           NaN
# 4                0           0.00K        0.00K          NaN           NaN
#
#    END_RANGE END_AZIMUTH MAGNITUDE_TYPE  MAGNITUDE  BEGIN_LAT  BEGIN_LON  \
# 0        NaN         NaN            NaN        NaN        NaN        NaN
# 1        NaN         NaN            NaN        NaN        NaN        NaN
# 2        NaN         NaN            NaN        NaN        NaN        NaN
# 3        NaN         NaN             EG       40.0        NaN        NaN
# 4        NaN         NaN            NaN        NaN        NaN        NaN
#
#    END_LAT  END_LON
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
df.shape
# Out:
# (59985, 22)

# %%
# assigning Hail to the missing magnitude types
df.loc[((df['MAGNITUDE_TYPE'].isnull()) & (df['MAGNITUDE'].isnull() == False)),'MAGNITUDE_TYPE'] = 'HA'
df.head()
# Out:
#            STATE CZ_TYPE      EVENT_TYPE     BEGIN_DATE_TIME CZ_TIMEZONE  \
# 0  NEW HAMPSHIRE       Z  Winter Weather  23-FEB-13 19:00:00       EST-5
# 1  NEW HAMPSHIRE       Z      Heavy Snow  14-DEC-13 21:00:00       EST-5
# 2  NEW HAMPSHIRE       Z      Heavy Snow  07-MAR-13 15:00:00       EST-5
# 3  NEW HAMPSHIRE       Z     Strong Wind  07-OCT-13 18:30:00       EST-5
# 4  NEW HAMPSHIRE       Z      Heavy Snow  08-FEB-13 15:00:00       EST-5
#
#         END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 0  25-FEB-13 04:00:00                0                  0              0
# 1  15-DEC-13 13:00:00                0                  0              0
# 2  09-MAR-13 09:00:00                0                  0              0
# 3  07-OCT-13 18:30:00                0                  0              0
# 4  09-FEB-13 17:00:00                0                  0              0
#
#    DEATHS_INDIRECT DAMAGE_PROPERTY DAMAGE_CROPS  BEGIN_RANGE BEGIN_AZIMUTH  \
# 0                0           0.00K        0.00K          NaN           NaN
# 1                0           0.00K        0.00K          NaN           NaN
# 2                0           0.00K        0.00K          NaN           NaN
# 3                0           3.00K        0.00K          NaN           NaN
# 4                0           0.00K        0.00K          NaN           NaN
#
#    END_RANGE END_AZIMUTH MAGNITUDE_TYPE  MAGNITUDE  BEGIN_LAT  BEGIN_LON  \
# 0        NaN         NaN            NaN        NaN        NaN        NaN
# 1        NaN         NaN            NaN        NaN        NaN        NaN
# 2        NaN         NaN            NaN        NaN        NaN        NaN
# 3        NaN         NaN             EG       40.0        NaN        NaN
# 4        NaN         NaN            NaN        NaN        NaN        NaN
#
#    END_LAT  END_LON
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
df['MAGNITUDE_TYPE'].value_counts()
# Out:
# EG    13716
# HA     9647
# MG     4620
# MS      503
# ES       24
# Name: MAGNITUDE_TYPE, dtype: int64

# %%
df = df.dropna(subset = ['MAGNITUDE','BEGIN_LAT','DAMAGE_PROPERTY'])
df.isnull().sum()
# Out:
# STATE                  0
# CZ_TYPE                0
# EVENT_TYPE             0
# BEGIN_DATE_TIME        0
# CZ_TIMEZONE            0
# END_DATE_TIME          0
# INJURIES_DIRECT        0
# INJURIES_INDIRECT      0
# DEATHS_DIRECT          0
# DEATHS_INDIRECT        0
# DAMAGE_PROPERTY        0
# DAMAGE_CROPS         737
# BEGIN_RANGE            0
# BEGIN_AZIMUTH          0
# END_RANGE              0
# END_AZIMUTH            0
# MAGNITUDE_TYPE         0
# MAGNITUDE              0
# BEGIN_LAT              0
# BEGIN_LON              0
# END_LAT                0
# END_LON                0
# dtype: int64

# %%
df.loc[df['DAMAGE_CROPS'].isnull(),'DAMAGE_CROPS'] = '0.00K'

# %%
df.isnull().sum()
# Out:
# STATE                0
# CZ_TYPE              0
# EVENT_TYPE           0
# BEGIN_DATE_TIME      0
# CZ_TIMEZONE          0
# END_DATE_TIME        0
# INJURIES_DIRECT      0
# INJURIES_INDIRECT    0
# DEATHS_DIRECT        0
# DEATHS_INDIRECT      0
# DAMAGE_PROPERTY      0
# DAMAGE_CROPS         0
# BEGIN_RANGE          0
# BEGIN_AZIMUTH        0
# END_RANGE            0
# END_AZIMUTH          0
# MAGNITUDE_TYPE       0
# MAGNITUDE            0
# BEGIN_LAT            0
# BEGIN_LON            0
# END_LAT              0
# END_LON              0
# dtype: int64

# %%
damage_dict = {'K': 10**3, 'M': 10**6, 'B': 10**9 }

df['YEAR'] = pd.to_datetime(df['BEGIN_DATE_TIME']).dt.year
df['BEGIN_MONTH'] = pd.to_datetime(df['BEGIN_DATE_TIME']).dt.month
df['BEGIN_DAY'] = pd.to_datetime(df['BEGIN_DATE_TIME']).dt.day
df['BEGIN_TIME'] = pd.to_datetime(df['BEGIN_DATE_TIME']).dt.time
df['END_MONTH'] = pd.to_datetime(df['END_DATE_TIME']).dt.month
df['END_DAY'] = pd.to_datetime(df['END_DATE_TIME']).dt.day
df['END_TIME'] = pd.to_datetime(df['END_DATE_TIME']).dt.time
df['DURATION_DAYS'] = (pd.to_datetime(df['END_DATE_TIME']) - pd.to_datetime(df['BEGIN_DATE_TIME'])).dt.days
df['DURATION_HOURS'] = (pd.to_datetime(df['END_DATE_TIME']) - pd.to_datetime(df['BEGIN_DATE_TIME'])).dt.seconds//3600
df['DURATION_MINUTES'] = ((pd.to_datetime(df['END_DATE_TIME']) - pd.to_datetime(df['BEGIN_DATE_TIME'])).dt.seconds//60)%60

df['DAMAGE_PROPERTY'] = df['DAMAGE_PROPERTY'].map(lambda x: float(x[:-1])*damage_dict[x[-1]])
df['DAMAGE_CROPS'] = df['DAMAGE_CROPS'].map(lambda x: float(x[:-1])*damage_dict[x[-1]] )
df.head(10)
# Out:
#        STATE CZ_TYPE         EVENT_TYPE     BEGIN_DATE_TIME CZ_TIMEZONE  \
# 11  MISSOURI       C               Hail  14-JUN-13 12:46:00       CST-6
# 13    KANSAS       C  Thunderstorm Wind  15-JUN-13 14:50:00       CST-6
# 14    KANSAS       C  Thunderstorm Wind  15-JUN-13 13:58:00       CST-6
# 15    KANSAS       C  Thunderstorm Wind  15-JUN-13 14:29:00       CST-6
# 16    KANSAS       C  Thunderstorm Wind  15-JUN-13 14:40:00       CST-6
# 17    KANSAS       C  Thunderstorm Wind  15-JUN-13 14:40:00       CST-6
# 38  MICHIGAN       C               Hail  30-MAY-13 14:18:00       EST-5
# 39  MICHIGAN       C               Hail  30-MAY-13 15:25:00       EST-5
# 40  MICHIGAN       C               Hail  30-MAY-13 15:35:00       EST-5
# 41  MICHIGAN       C               Hail  30-MAY-13 16:24:00       EST-5
#
#          END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# 11  14-JUN-13 12:46:00                0                  0              0
# 13  15-JUN-13 14:50:00                0                  0              0
# 14  15-JUN-13 13:58:00                0                  0              0
# 15  15-JUN-13 14:29:00                0                  0              0
# 16  15-JUN-13 14:40:00                0                  0              0
# 17  15-JUN-13 14:40:00                0                  0              0
# 38  30-MAY-13 14:18:00                0                  0              0
# 39  30-MAY-13 15:25:00                0                  0              0
# 40  30-MAY-13 15:35:00                0                  0              0
# 41  30-MAY-13 16:24:00                0                  0              0
#
#     DEATHS_INDIRECT  DAMAGE_PROPERTY  DAMAGE_CROPS  BEGIN_RANGE BEGIN_AZIMUTH  \
# 11                0              0.0           0.0          3.0             S
# 13                0            500.0           0.0          3.0             S
# 14                0            100.0           0.0          2.0           NNW
# 15                0              0.0           0.0          0.0             N
# 16                0              0.0           0.0          1.0            NE
# 17                0              0.0           0.0          0.0             N
# 38                0              0.0           0.0          1.0            SW
# 39                0              0.0           0.0          1.0             W
# 40                0              0.0           0.0          1.0            NW
# 41                0              0.0           0.0          3.0           ENE
#
#     END_RANGE END_AZIMUTH MAGNITUDE_TYPE  MAGNITUDE  BEGIN_LAT  BEGIN_LON  \
# 11        3.0           S             HA       1.00      40.53     -93.91
# 13        3.0           S             EG      52.00      38.91     -94.63
# 14        2.0         NNW             EG      52.00      38.53     -94.87
# 15        0.0           N             MG      54.00      38.98     -94.67
# 16        1.0          NE             EG      52.00      38.89     -94.81
# 17        0.0           N             MG      52.00      38.98     -94.67
# 38        1.0          SW             HA       1.75      43.61     -84.59
# 39        1.0           W             HA       0.75      43.75     -84.09
# 40        1.0          NW             HA       1.00      43.74     -83.99
# 41        3.0         ENE             HA       0.88      42.65     -83.17
#
#     END_LAT  END_LON  YEAR  BEGIN_MONTH  BEGIN_DAY BEGIN_TIME  END_MONTH  \
# 11    40.53   -93.91  2013            6         14   12:46:00          6
# 13    38.91   -94.63  2013            6         15   14:50:00          6
# 14    38.53   -94.87  2013            6         15   13:58:00          6
# 15    38.98   -94.67  2013            6         15   14:29:00          6
# 16    38.89   -94.81  2013            6         15   14:40:00          6
# 17    38.98   -94.67  2013            6         15   14:40:00          6
# 38    43.61   -84.59  2013            5         30   14:18:00          5
# 39    43.75   -84.09  2013            5         30   15:25:00          5
# 40    43.74   -83.99  2013            5         30   15:35:00          5
# 41    42.65   -83.17  2013            5         30   16:24:00          5
#
#     END_DAY  END_TIME  DURATION_DAYS  DURATION_HOURS  DURATION_MINUTES
# 11       14  12:46:00              0               0                 0
# 13       15  14:50:00              0               0                 0
# 14       15  13:58:00              0               0                 0
# 15       15  14:29:00              0               0                 0
# 16       15  14:40:00              0               0                 0
# 17       15  14:40:00              0               0                 0
# 38       30  14:18:00              0               0                 0
# 39       30  15:25:00              0               0                 0
# 40       30  15:35:00              0               0                 0
# 41       30  16:24:00              0               0                 0

# %%
df['EVENT_TYPE'].value_counts()
# Out:
# Thunderstorm Wind           12081
# Hail                         7340
# Marine Thunderstorm Wind     1283
# Marine High Wind               32
# Marine Hail                    18
# Marine Strong Wind              7
# Name: EVENT_TYPE, dtype: int64

# %%
df[df['DAMAGE_PROPERTY']>10000000]
# Out:
#                 STATE CZ_TYPE         EVENT_TYPE     BEGIN_DATE_TIME  \
# 21817           TEXAS       C               Hail  28-MAY-13 22:38:00
# 22055           TEXAS       C               Hail  28-MAY-13 22:40:00
# 22488           TEXAS       C               Hail  28-MAY-13 23:14:00
# 22718           TEXAS       C               Hail  28-MAY-13 23:15:00
# 22941           TEXAS       C               Hail  28-MAY-13 22:50:00
# 31851       MINNESOTA       C  Thunderstorm Wind  21-JUN-13 18:55:00
# 39731     MISSISSIPPI       C               Hail  18-MAR-13 14:32:00
# 39733     MISSISSIPPI       C               Hail  18-MAR-13 15:10:00
# 40153          KANSAS       C               Hail  07-APR-13 16:25:00
# 40377     MISSISSIPPI       C               Hail  18-MAR-13 15:10:00
# 42399           TEXAS       C  Thunderstorm Wind  05-JUN-13 21:30:00
# 42915     MISSISSIPPI       C               Hail  18-MAR-13 14:05:00
# 42922     MISSISSIPPI       C               Hail  18-MAR-13 14:30:00
# 43131     MISSISSIPPI       C               Hail  18-MAR-13 14:59:00
# 45103  GULF OF MEXICO       Z   Marine High Wind  03-APR-13 12:40:00
# 56867    SOUTH DAKOTA       C               Hail  30-AUG-13 13:30:00
#
#       CZ_TIMEZONE       END_DATE_TIME  INJURIES_DIRECT  INJURIES_INDIRECT  \
# 21817       CST-6  28-MAY-13 22:45:00                0                  0
# 22055       CST-6  28-MAY-13 22:51:00                0                  0
# 22488       CST-6  28-MAY-13 23:21:00                0                  0
# 22718       CST-6  28-MAY-13 23:24:00                0                  0
# 22941       CST-6  28-MAY-13 23:00:00                0                  0
# 31851       CST-6  21-JUN-13 18:57:00                0                  0
# 39731       CST-6  18-MAR-13 15:00:00                0                  0
# 39733       CST-6  18-MAR-13 15:40:00                0                  0
# 40153       CST-6  07-APR-13 16:25:00                0                  0
# 40377       CST-6  18-MAR-13 15:45:00                0                  0
# 42399       CST-6  05-JUN-13 21:41:00                0                  0
# 42915       CST-6  18-MAR-13 14:27:00                0                  0
# 42922       CST-6  18-MAR-13 15:05:00                1                  0
# 43131       CST-6  18-MAR-13 14:59:00                0                  0
# 45103       CST-6  03-APR-13 12:50:00                1                  0
# 56867       MST-7  30-AUG-13 13:40:00                0                  0
#
#        DEATHS_DIRECT  DEATHS_INDIRECT  DAMAGE_PROPERTY  DAMAGE_CROPS  \
# 21817              0                0       50000000.0           0.0
# 22055              0                0      200000000.0           0.0
# 22488              0                0      100000000.0           0.0
# 22718              0                0       50000000.0           0.0
# 22941              0                0       50000000.0           0.0
# 31851              0                0       17800000.0           0.0
# 39731              0                0       75000000.0           0.0
# 39733              0                0       75000000.0           0.0
# 40153              0                0       30000000.0           0.0
# 40377              0                0      100000000.0           0.0
# 42399              0                0      400000000.0      100000.0
# 42915              0                0       50000000.0           0.0
# 42922              0                0      200000000.0           0.0
# 43131              0                0       50000000.0           0.0
# 45103              1                0       12400000.0           0.0
# 56867              0                0       12000000.0           0.0
#
#        BEGIN_RANGE BEGIN_AZIMUTH  END_RANGE END_AZIMUTH MAGNITUDE_TYPE  \
# 21817          7.0           WSW        7.0         WSW             HA
# 22055          7.0           WSW        7.0         WSW             HA
# 22488          1.0           WSW        0.0         NNE             HA
# 22718          6.0             W        5.0           W             HA
# 22941          3.0           WSW        3.0         WSW             HA
# 31851          3.0             E        4.0           N             EG
# 39731          7.0           WNW        2.0         ESE             HA
# 39733          2.0            SW        2.0           N             HA
# 40153          1.0            NW        1.0          NW             HA
# 40377          3.0             N        1.0         SSW             HA
# 42399          4.0           WSW        4.0           S             MG
# 42915          3.0           NNE        5.0         NNE             HA
# 42922          7.0             W        2.0         SSE             HA
# 43131          2.0           SSE        2.0         SSE             HA
# 45103          0.0             N        0.0           N             MG
# 56867          2.0            SE        3.0         SSE             HA
#
#        MAGNITUDE  BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  YEAR  BEGIN_MONTH  \
# 21817       1.25    35.1600  -101.9400  35.1632 -101.9363  2013            5
# 22055       2.75    35.1743  -101.9399  35.1791 -101.9348  2013            5
# 22488       1.75    35.1950  -101.8319  35.2046 -101.8179  2013            5
# 22718       1.00    35.1933  -101.9245  35.2065 -101.9164  2013            5
# 22941       1.50    35.1832  -101.8682  35.1878 -101.8644  2013            5
# 31851      60.00    44.9490   -93.3007  44.9403  -93.2369  2013            6
# 39731       2.50    32.4103   -90.9860  32.3361  -90.7004  2013            3
# 39733       2.75    32.3267   -90.6949  32.2622  -90.3756  2013            3
# 40153       2.50    37.8400   -94.7100  37.8400  -94.7100  2013            4
# 40377       2.50    32.2878   -90.1648  32.1619  -89.7885  2013            3
# 42399      63.00    33.6400  -101.8800  33.5300 -101.8600  2013            6
# 42915       4.00    32.5666   -90.8370  32.5517  -90.6592  2013            3
# 42922       4.25    32.4705   -90.5960  32.2873  -90.1854  2013            3
# 43131       2.75    32.4100   -89.7600  32.4100  -89.7600  2013            3
# 45103      58.00    30.6800   -88.0300  30.6800  -88.0300  2013            4
# 56867       2.25    44.0617  -103.1970  44.0410 -103.2000  2013            8
#
#        BEGIN_DAY BEGIN_TIME  END_MONTH  END_DAY  END_TIME  DURATION_DAYS  \
# 21817         28   22:38:00          5       28  22:45:00              0
# 22055         28   22:40:00          5       28  22:51:00              0
# 22488         28   23:14:00          5       28  23:21:00              0
# 22718         28   23:15:00          5       28  23:24:00              0
# 22941         28   22:50:00          5       28  23:00:00              0
# 31851         21   18:55:00          6       21  18:57:00              0
# 39731         18   14:32:00          3       18  15:00:00              0
# 39733         18   15:10:00          3       18  15:40:00              0
# 40153          7   16:25:00          4        7  16:25:00              0
# 40377         18   15:10:00          3       18  15:45:00              0
# 42399          5   21:30:00          6        5  21:41:00              0
# 42915         18   14:05:00          3       18  14:27:00              0
# 42922         18   14:30:00          3       18  15:05:00              0
# 43131         18   14:59:00          3       18  14:59:00              0
# 45103          3   12:40:00          4        3  12:50:00              0
# 56867         30   13:30:00          8       30  13:40:00              0
#
#        DURATION_HOURS  DURATION_MINUTES
# 21817               0                 7
# 22055               0                11
# 22488               0                 7
# 22718               0                 9
# 22941               0                10
# 31851               0                 2
# 39731               0                28
# 39733               0                30
# 40153               0                 0
# 40377               0                35
# 42399               0                11
# 42915               0                22
# 42922               0                35
# 43131               0                 0
# 45103               0                10
# 56867               0                10

# %%
df['EVENT_TYPE'].value_counts()
# Out:
# Thunderstorm Wind           12081
# Hail                         7340
# Marine Thunderstorm Wind     1283
# Marine High Wind               32
# Marine Hail                    18
# Marine Strong Wind              7
# Name: EVENT_TYPE, dtype: int64

# %%
df.dtypes
# Out:
# STATE                 object
# CZ_TYPE               object
# EVENT_TYPE            object
# BEGIN_DATE_TIME       object
# CZ_TIMEZONE           object
# END_DATE_TIME         object
# INJURIES_DIRECT        int64
# INJURIES_INDIRECT      int64
# DEATHS_DIRECT          int64
# DEATHS_INDIRECT        int64
# DAMAGE_PROPERTY      float64
# DAMAGE_CROPS         float64
# BEGIN_RANGE          float64
# BEGIN_AZIMUTH         object
# END_RANGE            float64
# END_AZIMUTH           object
# MAGNITUDE_TYPE        object
# MAGNITUDE            float64
# BEGIN_LAT            float64
# BEGIN_LON            float64
# END_LAT              float64
# END_LON              float64
# YEAR                   int64
# BEGIN_MONTH            int64
# BEGIN_DAY              int64
# BEGIN_TIME            object
# END_MONTH              int64
# END_DAY                int64
# END_TIME              object
# DURATION_DAYS          int64
# DURATION_HOURS         int64
# DURATION_MINUTES       int64
# dtype: object

# %% [raw]
# import shapefile
# sf = shapefile.Reader('tl_2010_us_state10/tl_2010_us_state10')
# print ('number of shapes imported:',len(sf.shapes()))
# shape_ex = sf.shape(5)
#
# x_lon = np.zeros((len(shape_ex.points),1))
# y_lat = np.zeros((len(shape_ex.points),1))
# for ip in range(len(shape_ex.points)):
#     x_lon[ip] = shape_ex.points[ip][0]
#     y_lat[ip] = shape_ex.points[ip][1]
#
# plt.plot(x_lon,y_lat,'k')
# plt.xlim(shape_ex.bbox[0],shape_ex.bbox[2])

# %%
import shapefile
sf = shapefile.Reader('tl_2010_us_state10/tl_2010_us_state10')
plt.figure(figsize = (15,18))
ax = plt.axes()
ax.set_aspect('equal')
for shape in list(sf.iterShapes()):
   x_lon = np.zeros((len(shape.points),1))
   y_lat = np.zeros((len(shape.points),1))
   for ip in range(len(shape.points)):
       x_lon[ip] = shape.points[ip][0]
       y_lat[ip] = shape.points[ip][1]

   plt.plot(x_lon,y_lat)

plt.xlim(-130,-60)
plt.ylim(23,50)

# %%
plt.figure(figsize = (8,8))
for index, row in df.iterrows():
    plt.plot([row['BEGIN_LON'],row['END_LON']], [row['BEGIN_LAT'],row['END_LAT']], color = 'b')
    plt.xlim(-125, -80)
    plt.ylim(24,49)
