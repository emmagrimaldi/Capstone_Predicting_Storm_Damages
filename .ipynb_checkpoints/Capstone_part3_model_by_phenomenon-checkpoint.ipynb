# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import metrics, regularizers
from keras.utils import to_categorical


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 500)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
df = pd.read_csv('2000-2018_disasters_min50k_for_modeling.csv')
df.drop(columns = ['BEGIN_DATE_TIME','END_DATE_TIME','BEGIN_TIME','END_TIME'], inplace = True)
df.head()
# Out:
#       STATE CZ_TYPE         EVENT_TYPE CZ_TIMEZONE  INJURIES_DIRECT  \
# 0  MISSOURI       C  Thunderstorm Wind         CST                3
# 1  ILLINOIS       C  Thunderstorm Wind         CST                0
# 2  ILLINOIS       C  Thunderstorm Wind         CST                0
# 3   INDIANA       C  Thunderstorm Wind         CST                0
# 4  ILLINOIS       C  Thunderstorm Wind         CST                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT  DAMAGE_PROPERTY  \
# 0                  0              0                0         250000.0
# 1                  0              0                0         150000.0
# 2                  0              0                0         100000.0
# 3                  0              0                0         100000.0
# 4                  0              0                0         100000.0
#
#    DAMAGE_CROPS  BEGIN_RANGE BEGIN_AZIMUTH  END_RANGE END_AZIMUTH  \
# 0           0.0          1.0             E        0.0           N
# 1           0.0          2.0            NE        4.0          NE
# 2           0.0          1.0             S        4.0          NE
# 3           0.0          0.0             E        0.0           E
# 4           0.0          0.0             E        1.0           E
#
#   MAGNITUDE_TYPE  MAGNITUDE  BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  YEAR  \
# 0              E       83.0      37.25     -89.67    37.30   -89.53  2000
# 1              E      100.0      37.73     -89.18    37.75   -89.17  2000
# 2              E       75.0      37.78     -89.12    37.78   -89.12  2000
# 3              E       65.0      37.98     -87.55    37.98   -87.55  2000
# 4              E       87.0      37.73     -88.93    37.73   -88.93  2000
#
#    BEGIN_MONTH  BEGIN_DAY  END_MONTH  END_DAY  DURATION_DAYS  DURATION_HOURS  \
# 0            1          3          1        3              0               0
# 1            1          3          1        3              0               0
# 2            1          3          1        3              0               0
# 3            1          3          1        3              0               0
# 4            1          3          1        3              0               0
#
#    DURATION_MINUTES  TOTAL_DURATION_HR  DISTANCE_COVERED(KM)  BEGIN_HOUR  \
# 0                10                0.2             16.651331           8
# 1                 4                0.1              4.535308           9
# 2                 2                0.0              0.000000           9
# 3                 0                0.0              0.000000          12
# 4                 0                0.0              0.000000          14
#
#    BEGIN_MINUTE  END_HOUR  END_MINUTE
# 0            50         9           0
# 1            18         9          22
# 2            22         9          24
# 3            10        12          10
# 4             7        14           7

# %%
df['EVENT_TYPE'].value_counts()
# Out:
# Thunderstorm Wind           8085
# Hail                        2944
# Marine Thunderstorm Wind       5
# Tornado                        5
# Marine High Wind               4
# Flash Flood                    2
# Marine Strong Wind             2
# Name: EVENT_TYPE, dtype: int64

# %%
features = ['BEGIN_RANGE', 'END_RANGE', 'MAGNITUDE', 'BEGIN_AZIMUTH',
            'BEGIN_MONTH', 'END_MONTH', 'TOTAL_DURATION_HR', 'DISTANCE_COVERED(KM)', 'BEGIN_HOUR', 'STATE']

len(features)
# Out:
# 10

# %%
# function to calculate r^2 of my neural network
def r_square(X_test,y_test):
    y_pred = model.predict(X_test).reshape(y_test.shape[0])
    y_test = np.array(y_test)
    ss_res = np.sum(np.square(y_test - y_pred))
    y_mean = np.full((1, y_test.shape[0]),y_test.mean())
    ss_tot = np.sum(np.square(y_mean - y_test))
    return 1-ss_res/ss_tot

# %% [markdown]
# # Hail events

# %%
hail = df[df['EVENT_TYPE'] == 'Hail']
hail.shape
# Out:
# (2944, 34)

# %%
hail['MAGNITUDE'].min()
# Out:
# 0.25

# %%
hail['MAGNITUDE'].max()
# Out:
# 7.0

# %%
hail['DAMAGE_PROPERTY'].min()
# Out:
# 51000.0

# %%
hail['DAMAGE_PROPERTY'].max()
# Out:
# 2300000000.0

# %%
hail[hail['DAMAGE_PROPERTY'] == hail['DAMAGE_PROPERTY'].max()]
# Out:
#           STATE CZ_TYPE EVENT_TYPE CZ_TIMEZONE  INJURIES_DIRECT  \
# 10512  COLORADO       C       Hail       MST-7                0
#
#        INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT  DAMAGE_PROPERTY  \
# 10512                  0              0                0     2.300000e+09
#
#        DAMAGE_CROPS  BEGIN_RANGE BEGIN_AZIMUTH  END_RANGE END_AZIMUTH  \
# 10512           0.0          1.0             N        1.0           N
#
#       MAGNITUDE_TYPE  MAGNITUDE  BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  YEAR  \
# 10512             HA       2.75      39.77     -105.1    39.77   -105.1  2017
#
#        BEGIN_MONTH  BEGIN_DAY  END_MONTH  END_DAY  DURATION_DAYS  \
# 10512            5          8          5        8              0
#
#        DURATION_HOURS  DURATION_MINUTES  TOTAL_DURATION_HR  \
# 10512               0                 0                0.0
#
#        DISTANCE_COVERED(KM)  BEGIN_HOUR  BEGIN_MINUTE  END_HOUR  END_MINUTE
# 10512                   0.0          14             5        14           5

# %%
plt.scatter(hail['MAGNITUDE'], hail['DAMAGE_PROPERTY'])

# %%
plt.scatter(hail['TOTAL_DURATION_HR'], hail['DAMAGE_PROPERTY'])

# %%
hail = hail[(hail['DAMAGE_PROPERTY']<1000000) & (hail['TOTAL_DURATION_HR']>0) ]
plt.scatter(hail['TOTAL_DURATION_HR'], hail['DAMAGE_PROPERTY'])

# %%
plt.scatter(hail['MAGNITUDE'], hail['DAMAGE_PROPERTY'])

# %%
X = hail[features]
X = pd.get_dummies(X)
y = hail['DAMAGE_PROPERTY']

X.head()
# Out:
#     BEGIN_RANGE  END_RANGE  MAGNITUDE  BEGIN_MONTH  END_MONTH  \
# 26          0.0        2.0       1.50            3          3
# 38          6.0       14.0       1.50            3          3
# 41          4.0        4.0       4.50            3          3
# 42          6.0       14.0       3.50            3          3
# 47          2.0        2.0       1.75            3          3
#
#     TOTAL_DURATION_HR  DISTANCE_COVERED(KM)  BEGIN_HOUR  BEGIN_AZIMUTH_E  \
# 26                0.6             34.393638           2                0
# 38                0.5             22.758296          21                0
# 41                0.2              0.000000          17                0
# 42                0.2              0.000000          17                0
# 47                0.4             15.691054          18                0
#
#     BEGIN_AZIMUTH_ENE  BEGIN_AZIMUTH_ESE  BEGIN_AZIMUTH_N  BEGIN_AZIMUTH_NE  \
# 26                  0                  0                0                 0
# 38                  0                  0                0                 1
# 41                  0                  0                1                 0
# 42                  0                  0                0                 1
# 47                  0                  0                0                 0
#
#     BEGIN_AZIMUTH_NNE  BEGIN_AZIMUTH_NNW  BEGIN_AZIMUTH_NW  BEGIN_AZIMUTH_S  \
# 26                  1                  0                 0                0
# 38                  0                  0                 0                0
# 41                  0                  0                 0                0
# 42                  0                  0                 0                0
# 47                  0                  0                 0                0
#
#     BEGIN_AZIMUTH_SE  BEGIN_AZIMUTH_SSE  BEGIN_AZIMUTH_SSW  BEGIN_AZIMUTH_SW  \
# 26                 0                  0                  0                 0
# 38                 0                  0                  0                 0
# 41                 0                  0                  0                 0
# 42                 0                  0                  0                 0
# 47                 0                  0                  0                 0
#
#     BEGIN_AZIMUTH_W  BEGIN_AZIMUTH_WNW  BEGIN_AZIMUTH_WSW  STATE_ALABAMA  \
# 26                0                  0                  0              0
# 38                0                  0                  0              0
# 41                0                  0                  0              0
# 42                0                  0                  0              0
# 47                0                  0                  1              0
#
#     STATE_ARIZONA  STATE_ARKANSAS  STATE_CALIFORNIA  STATE_COLORADO  \
# 26              0               0                 1               0
# 38              0               0                 0               0
# 41              0               0                 0               0
# 42              0               0                 0               0
# 47              0               0                 0               0
#
#     STATE_CONNECTICUT  STATE_FLORIDA  STATE_GEORGIA  STATE_IDAHO  \
# 26                  0              0              0            0
# 38                  0              0              0            0
# 41                  0              0              0            0
# 42                  0              0              0            0
# 47                  0              0              0            0
#
#     STATE_ILLINOIS  STATE_INDIANA  STATE_IOWA  STATE_KANSAS  STATE_KENTUCKY  \
# 26               0              0           0             0               0
# 38               0              0           0             0               0
# 41               0              0           0             0               0
# 42               0              0           0             0               0
# 47               0              0           0             0               0
#
#     STATE_LOUISIANA  STATE_MASSACHUSETTS  STATE_MICHIGAN  STATE_MINNESOTA  \
# 26                0                    0               0                0
# 38                0                    0               0                0
# 41                0                    0               0                0
# 42                0                    0               0                0
# 47                0                    0               0                0
#
#     STATE_MISSISSIPPI  STATE_MISSOURI  STATE_MONTANA  STATE_NEBRASKA  \
# 26                  0               0              0               0
# 38                  0               0              0               0
# 41                  0               0              0               0
# 42                  0               0              0               0
# 47                  0               0              0               0
#
#     STATE_NEW JERSEY  STATE_NEW MEXICO  STATE_NEW YORK  STATE_NORTH CAROLINA  \
# 26                 0                 0               0                     0
# 38                 0                 0               0                     0
# 41                 0                 0               0                     0
# 42                 0                 0               0                     0
# 47                 0                 0               0                     0
#
#     STATE_NORTH DAKOTA  STATE_OHIO  STATE_OKLAHOMA  STATE_PENNSYLVANIA  \
# 26                   0           0               0                   0
# 38                   0           0               0                   0
# 41                   0           0               0                   0
# 42                   0           0               0                   0
# 47                   0           0               0                   0
#
#     STATE_PUERTO RICO  STATE_SOUTH CAROLINA  STATE_SOUTH DAKOTA  \
# 26                  0                     0                   0
# 38                  0                     0                   0
# 41                  0                     0                   0
# 42                  0                     0                   0
# 47                  0                     0                   0
#
#     STATE_TENNESSEE  STATE_TEXAS  STATE_UTAH  STATE_VERMONT  STATE_VIRGINIA  \
# 26                0            0           0              0               0
# 38                0            1           0              0               0
# 41                0            1           0              0               0
# 42                0            1           0              0               0
# 47                0            1           0              0               0
#
#     STATE_WEST VIRGINIA  STATE_WISCONSIN  STATE_WYOMING
# 26                    0                0              0
# 38                    0                0              0
# 41                    0                0              0
# 42                    0                0              0
# 47                    0                0              0

# %%
X.shape
# Out:
# (939, 65)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 18)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
model = Sequential()

# input layer 
model.add(Dense(65, activation = 'relu', input_dim = X_train.shape[1]))

# adding a hidden layer 
model.add(Dense(500, activation = 'relu'))

model.add(Dropout(0.3))

# adding a hidden layer 
model.add(Dense(500, activation = 'relu'))

model.add(Dropout(0.3))

# output layer
model.add(Dense(1, activation = None))

model.compile(loss = 'mean_absolute_error', optimizer = 'adam')

history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 10000, verbose = 0)

# %%
plt.figure(figsize=(10,8))
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend();

# %%
r_square(X_train, y_train)
# Out:
# 0.987015874475448

# %%
r_square(X_test, y_test)
# Out:
# -1.8330286011184485

# %% [markdown]
# # Thunderstorm wind events

# %%
thun = df[df['EVENT_TYPE'] == 'Thunderstorm Wind']
thun.shape
# Out:
# (8085, 34)

# %%
thun['DAMAGE_PROPERTY'].min()
# Out:
# 51000.0

# %%
thun['DAMAGE_PROPERTY'].max()
# Out:
# 750000000.0

# %%
plt.scatter(thun['MAGNITUDE'], thun['DAMAGE_PROPERTY'])

# %%
plt.scatter(thun['TOTAL_DURATION_HR'], thun['DAMAGE_PROPERTY'])

# %%
thun = thun[(thun['DAMAGE_PROPERTY']<1000000) & (thun['TOTAL_DURATION_HR']>0) & (thun['DISTANCE_COVERED(KM)']>0)]

# %%
thun.shape
# Out:
# (2069, 34)

# %%
plt.scatter(thun['MAGNITUDE'], thun['DAMAGE_PROPERTY'])

# %%
plt.scatter(thun['TOTAL_DURATION_HR'], thun['DAMAGE_PROPERTY'])
plt.xlim(-0.1,3)
# Out:
# (-0.1, 3)

# %%
X = thun[features]
X = pd.get_dummies(X)
y = thun['DAMAGE_PROPERTY']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
X_train.shape
# Out:
# (1551, 72)

# %%
model = Sequential()

# input layer 
model.add(Dense(72, activation = 'relu', input_dim = X_train.shape[1]))

# adding a hidden layer 
model.add(Dense(500, activation = 'relu'))

model.add(Dropout(0.5))

# adding a hidden layer 
model.add(Dense(500, activation = 'relu'))

model.add(Dropout(0.5))

# output layer
model.add(Dense(1, activation = None))

model.compile(loss = 'mean_absolute_error', optimizer = 'adam')

history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 10000, verbose = 0)

# %%
plt.figure(figsize=(10,8))
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend();

# %%
r_square(X_train, y_train)
# Out:
# 0.9797685749290281

# %%
r_square(X_test, y_test)
# Out:
# -2.2724070589499403
